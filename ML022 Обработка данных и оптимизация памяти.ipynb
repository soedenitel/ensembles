# %% [markdown]
# ## Постановка задачи
# Загрузим данные и подготовим все данные для анализа: проведем нормализацию и преобразование категорий. Оптимизируем потребление памяти.
#
# Разделим выборку на обучающую/проверочную в соотношении 80/20.
#
# Применим наивный Байес для классификации скоринга. Будем использовать все возможные столбцы.
#
# Проверим качество предсказания через каппа-метрику и матрицу неточностей.
#
# Данные:
# * https://video.ittensive.com/machine-learning/prudential/train.csv.gz
#
# Соревнование: https://www.kaggle.com/c/prudential-life-insurance-assessment/
#
# © ITtensive, 2020

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn import preprocessing
import re
from etl_utils import reduce_mem_usage, show_inf_and_na, inf_and_na_columns
pd.set_option('display.max_columns', 200)

data = pd.read_csv("https://video.ittensive.com/machine-learning/prudential/train.csv.gz")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.0+ MB

# %% [markdown]
# ###  Категоризация данных и оптимизация потребления памяти

# %%
data['Product_Info_2_1'] = data['Product_Info_2'].str.slice(0, 1)
data['Product_Info_2_2'] = pd.to_numeric(data['Product_Info_2'].str.slice(1, 2))
data = reduce_mem_usage(data.drop('Product_Info_2', axis='columns'))
data.info()
# Out:
# Потребление памяти меньше на 49.89 Мб (-85.4%)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 129 entries, Id to Product_Info_2_2
# dtypes: category(1), float16(18), int16(1), int32(1), int8(108)
# memory usage: 8.6 MB

# %% [markdown]
# ### Предобработка: категоризация, единичные векторы
# | Product |
# | - |
# | A |
# | B |
# | C |
# | A |
#
# Переходит в
#
# | ProductA | ProductB | ProductC |
# | -- | -- | -- |
# | 1 | 0 | 0 |
# | 0 | 1 | 0 |
# | 0 | 0 | 1 |
# | 1 | 0 | 0 |
#
# Можно использовать sklearn.preprocessing.OneHotEncoder, но для этого потребуется дополнительно преобразовать фрейм данных (набор единичных векторов для каждого кортежа данных).
#
# Также не будем использовать кодирование категорий (A->1, B->2, C->3, D->4, E->5), потому что это переводит номинативную случайную величину в ранговую/числовую, и является существенным допущением относительно исходных данных.

# %%
# %%time
onehot_df = pd.get_dummies(data['Product_Info_2_1'])
onehot_df.columns = ['Product_Info_2_1' + column for column in onehot_df.columns]
data = pd.merge(left=data, right=onehot_df, left_index=True, right_index=True).drop('Product_Info_2_1', axis=1)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 19 ms

# %% [markdown]
# ### Заполним отсутствующие значения
# -1 увеличивает "расстояние" при расчете ближайших соседей

# %%
data.fillna(-1, inplace=True)

# %% [markdown]
# ### Столбцы для модели

# %%
feature_regsearcher = r'Insurance_History.*|InsuredInfo.*|Medical_Keyword|Family_Hist.*|Medical_History.*|Product_Info.*|Wt|Ht|Ins_Age|BMI'
columns = [column for column in data.columns if re.match(feature_regsearcher, column) != None]
columns
# Out:
# ['Product_Info_1',
#  'Product_Info_3',
#  'Product_Info_4',
#  'Product_Info_5',
#  'Product_Info_6',
#  'Product_Info_7',
#  'Ins_Age',
#  'Ht',
#  'Wt',
#  'BMI',
#  'InsuredInfo_1',
#  'InsuredInfo_2',
#  'InsuredInfo_3',
#  'InsuredInfo_4',
#  'InsuredInfo_5',
#  'InsuredInfo_6',
#  'InsuredInfo_7',
#  'Insurance_History_1',
#  'Insurance_History_2',
#  'Insurance_History_3',
#  'Insurance_History_4',
#  'Insurance_History_5',
#  'Insurance_History_7',
#  'Insurance_History_8',
#  'Insurance_History_9',
#  'Family_Hist_1',
#  'Family_Hist_2',
#  'Family_Hist_3',
#  'Family_Hist_4',
#  'Family_Hist_5',
#  'Medical_History_1',
#  'Medical_History_2',
#  'Medical_History_3',
#  'Medical_History_4',
#  'Medical_History_5',
#  'Medical_History_6',
#  'Medical_History_7',
#  'Medical_History_8',
#  'Medical_History_9',
#  'Medical_History_10',
#  'Medical_History_11',
#  'Medical_History_12',
#  'Medical_History_13',
#  'Medical_History_14',
#  'Medical_History_15',
#  'Medical_History_16',
#  'Medical_History_17',
#  'Medical_History_18',
#  'Medical_History_19',
#  'Medical_History_20',
#  'Medical_History_21',
#  'Medical_History_22',
#  'Medical_History_23',
#  'Medical_History_24',
#  'Medical_History_25',
#  'Medical_History_26',
#  'Medical_History_27',
#  'Medical_History_28',
#  'Medical_History_29',
#  'Medical_History_30',
#  'Medical_History_31',
#  'Medical_History_32',
#  'Medical_History_33',
#  'Medical_History_34',
#  'Medical_History_35',
#  'Medical_History_36',
#  'Medical_History_37',
#  'Medical_History_38',
#  'Medical_History_39',
#  'Medical_History_40',
#  'Medical_History_41',
#  'Medical_Keyword_1',
#  'Medical_Keyword_2',
#  'Medical_Keyword_3',
#  'Medical_Keyword_4',
#  'Medical_Keyword_5',
#  'Medical_Keyword_6',
#  'Medical_Keyword_7',
#  'Medical_Keyword_8',
#  'Medical_Keyword_9',
#  'Medical_Keyword_10',
#  'Medical_Keyword_11',
#  'Medical_Keyword_12',
#  'Medical_Keyword_13',
#  'Medical_Keyword_14',
#  'Medical_Keyword_15',
#  'Medical_Keyword_16',
#  'Medical_Keyword_17',
#  'Medical_Keyword_18',
#  'Medical_Keyword_19',
#  'Medical_Keyword_20',
#  'Medical_Keyword_21',
#  'Medical_Keyword_22',
#  'Medical_Keyword_23',
#  'Medical_Keyword_24',
#  'Medical_Keyword_25',
#  'Medical_Keyword_26',
#  'Medical_Keyword_27',
#  'Medical_Keyword_28',
#  'Medical_Keyword_29',
#  'Medical_Keyword_30',
#  'Medical_Keyword_31',
#  'Medical_Keyword_32',
#  'Medical_Keyword_33',
#  'Medical_Keyword_34',
#  'Medical_Keyword_35',
#  'Medical_Keyword_36',
#  'Medical_Keyword_37',
#  'Medical_Keyword_38',
#  'Medical_Keyword_39',
#  'Medical_Keyword_40',
#  'Medical_Keyword_41',
#  'Medical_Keyword_42',
#  'Medical_Keyword_43',
#  'Medical_Keyword_44',
#  'Medical_Keyword_45',
#  'Medical_Keyword_46',
#  'Medical_Keyword_47',
#  'Medical_Keyword_48',
#  'Product_Info_2_2',
#  'Product_Info_2_1A',
#  'Product_Info_2_1B',
#  'Product_Info_2_1C',
#  'Product_Info_2_1D',
#  'Product_Info_2_1E']

# %% [markdown]
# ### Предобработка данных
# Дополнительно проведем z-нормализацию данных через предварительную обработку (preprocessing). Нормализуем весь исходный набор данных.

# %%
scaler = preprocessing.StandardScaler().fit(data[columns])

# %% [markdown]
# ### Разделение данных

# %%
data_train, data_test = train_test_split(data, test_size=0.2)
data_train.head()
# Out:
#           Id  Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 39782  52834               1              10        0.076904               2
# 33811  44885               1              26        0.076904               2
# 32320  42872               1              26        0.487061               2
# 32742  43439               1              26        0.230713               2
# 55958  74542               1              26        0.487061               2
#
#        Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt       BMI  \
# 39782               3               1  0.268555  0.636230  0.320068  0.609375
# 33811               3               1  0.656738  0.654785  0.322266  0.589355
# 32320               1               1  0.268555  0.799805  0.330566  0.441895
# 32742               3               1  0.193970  0.654785  0.188232  0.337646
# 55958               3               1  0.432861  0.672852  0.393311  0.695801
#
#        Employment_Info_1  Employment_Info_2  Employment_Info_3  \
# 39782           0.070007                  1                  3
# 33811           0.031204                  1                  3
# 32320           0.114990                  9                  1
# 32742           0.045013                  9                  1
# 55958           0.094971                  3                  1
#
#        Employment_Info_4  Employment_Info_5  Employment_Info_6  InsuredInfo_1  \
# 39782                0.0                  3           0.000000              1
# 33811                0.0                  2           0.000000              1
# 32320                0.0                  2           0.250000              2
# 32742                0.0                  2           0.150024              1
# 55958               -1.0                  2           0.350098              1
#
#        InsuredInfo_2  InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  \
# 39782              2              3              3              1
# 33811              2              8              3              1
# 32320              2              3              3              1
# 32742              2              5              3              1
# 55958              2              3              3              1
#
#        InsuredInfo_6  InsuredInfo_7  Insurance_History_1  Insurance_History_2  \
# 39782              2              1                    2                    1
# 33811              2              1                    2                    1
# 32320              1              1                    2                    1
# 32742              2              1                    2                    1
# 55958              1              1                    2                    1
#
#        Insurance_History_3  Insurance_History_4  Insurance_History_5  \
# 39782                    1                    3                 -1.0
# 33811                    1                    3                 -1.0
# 32320                    1                    3                 -1.0
# 32742                    1                    3                 -1.0
# 55958                    1                    3                 -1.0
#
#        Insurance_History_7  Insurance_History_8  Insurance_History_9  \
# 39782                    3                    2                    3
# 33811                    3                    2                    3
# 32320                    3                    2                    3
# 32742                    3                    2                    3
# 55958                    3                    2                    3
#
#        Family_Hist_1  Family_Hist_2  Family_Hist_3  Family_Hist_4  \
# 39782              1      -1.000000      -1.000000      -1.000000
# 33811              3      -1.000000       0.519531      -1.000000
# 32320              2       0.507324      -1.000000       0.408447
# 32742              3       0.376709      -1.000000       0.309814
# 55958              2      -1.000000      -1.000000      -1.000000
#
#        Family_Hist_5  Medical_History_1  Medical_History_2  Medical_History_3  \
# 39782      -1.000000                1.0                112                  2
# 33811       0.606934                1.0                 16                  2
# 32320      -1.000000                0.0                491                  2
# 32742      -1.000000               22.0                161                  2
# 55958       0.294678                5.0                112                  2
#
#        Medical_History_4  Medical_History_5  Medical_History_6  \
# 39782                  1                  1                  1
# 33811                  2                  1                  3
# 32320                  2                  1                  3
# 32742                  2                  1                  3
# 55958                  1                  1                  1
#
#        Medical_History_7  Medical_History_8  Medical_History_9  \
# 39782                  2                  2                  1
# 33811                  2                  2                  1
# 32320                  2                  2                  2
# 32742                  2                  2                  1
# 55958                  2                  2                  1
#
#        Medical_History_10  Medical_History_11  Medical_History_12  \
# 39782                -1.0                   3                   2
# 33811                -1.0                   3                   2
# 32320                -1.0                   3                   2
# 32742                -1.0                   3                   2
# 55958                -1.0                   3                   2
#
#        Medical_History_13  Medical_History_14  Medical_History_15  \
# 39782                   1                   3                 0.0
# 33811                   3                   3                -1.0
# 32320                   3                   3                -1.0
# 32742                   3                   3                -1.0
# 55958                   1                   3                -1.0
#
#        Medical_History_16  Medical_History_17  Medical_History_18  \
# 39782                   3                   3                   1
# 33811                   3                   3                   1
# 32320                   1                   3                   1
# 32742                   1                   3                   1
# 55958                   1                   3                   1
#
#        Medical_History_19  Medical_History_20  Medical_History_21  \
# 39782                   1                   2                   1
# 33811                   1                   2                   1
# 32320                   1                   2                   1
# 32742                   1                   2                   2
# 55958                   1                   2                   1
#
#        Medical_History_22  Medical_History_23  Medical_History_24  \
# 39782                   2                   3                -1.0
# 33811                   2                   3                -1.0
# 32320                   2                   1                -1.0
# 32742                   2                   3                -1.0
# 55958                   2                   1                -1.0
#
#        Medical_History_25  Medical_History_26  Medical_History_27  \
# 39782                   1                   3                   3
# 33811                   2                   2                   3
# 32320                   1                   3                   3
# 32742                   2                   2                   3
# 55958                   1                   3                   3
#
#        Medical_History_28  Medical_History_29  Medical_History_30  \
# 39782                   1                   1                   2
# 33811                   1                   1                   2
# 32320                   1                   3                   2
# 32742                   1                   3                   2
# 55958                   1                   3                   2
#
#        Medical_History_31  Medical_History_32  Medical_History_33  \
# 39782                   3                -1.0                   3
# 33811                   3                -1.0                   3
# 32320                   3                -1.0                   3
# 32742                   3                -1.0                   3
# 55958                   3                -1.0                   3
#
#        Medical_History_34  Medical_History_35  Medical_History_36  \
# 39782                   1                   1                   2
# 33811                   3                   1                   3
# 32320                   3                   1                   2
# 32742                   1                   1                   3
# 55958                   3                   1                   2
#
#        Medical_History_37  Medical_History_38  Medical_History_39  \
# 39782                   2                   1                   3
# 33811                   2                   1                   3
# 32320                   2                   1                   1
# 32742                   2                   1                   3
# 55958                   2                   1                   1
#
#        Medical_History_40  Medical_History_41  Medical_Keyword_1  \
# 39782                   3                   1                  0
# 33811                   3                   3                  0
# 32320                   3                   3                  0
# 32742                   3                   3                  0
# 55958                   3                   1                  0
#
#        Medical_Keyword_2  Medical_Keyword_3  Medical_Keyword_4  \
# 39782                  0                  0                  1
# 33811                  0                  0                  0
# 32320                  0                  1                  0
# 32742                  0                  0                  0
# 55958                  0                  1                  0
#
#        Medical_Keyword_5  Medical_Keyword_6  Medical_Keyword_7  \
# 39782                  0                  1                  0
# 33811                  0                  0                  0
# 32320                  0                  0                  0
# 32742                  0                  0                  0
# 55958                  0                  0                  0
#
#        Medical_Keyword_8  Medical_Keyword_9  Medical_Keyword_10  \
# 39782                  0                  0                   0
# 33811                  0                  0                   0
# 32320                  0                  0                   0
# 32742                  1                  0                   0
# 55958                  0                  0                   0
#
#        Medical_Keyword_11  Medical_Keyword_12  Medical_Keyword_13  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_14  Medical_Keyword_15  Medical_Keyword_16  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   1                   0
# 32742                   0                   0                   0
# 55958                   0                   1                   0
#
#        Medical_Keyword_17  Medical_Keyword_18  Medical_Keyword_19  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_20  Medical_Keyword_21  Medical_Keyword_22  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_23  Medical_Keyword_24  Medical_Keyword_25  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   1
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_26  Medical_Keyword_27  Medical_Keyword_28  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   1                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_29  Medical_Keyword_30  Medical_Keyword_31  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_32  Medical_Keyword_33  Medical_Keyword_34  \
# 39782                   0                   0                   0
# 33811                   0                   1                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   1                   0
#
#        Medical_Keyword_35  Medical_Keyword_36  Medical_Keyword_37  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_38  Medical_Keyword_39  Medical_Keyword_40  \
# 39782                   0                   0                   1
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_41  Medical_Keyword_42  Medical_Keyword_43  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_44  Medical_Keyword_45  Medical_Keyword_46  \
# 39782                   0                   0                   0
# 33811                   0                   0                   0
# 32320                   0                   0                   0
# 32742                   0                   0                   0
# 55958                   0                   0                   0
#
#        Medical_Keyword_47  Medical_Keyword_48  Response  Product_Info_2_2  \
# 39782                   0                   1         1                 3
# 33811                   0                   0         2                 2
# 32320                   0                   0         5                 5
# 32742                   0                   0         8                 5
# 55958                   0                   1         2                 2
#
#        Product_Info_2_1A  Product_Info_2_1B  Product_Info_2_1C  \
# 39782                  0                  0                  0
# 33811                  0                  0                  0
# 32320                  1                  0                  0
# 32742                  1                  0                  0
# 55958                  0                  0                  0
#
#        Product_Info_2_1D  Product_Info_2_1E
# 39782                  1                  0
# 33811                  1                  0
# 32320                  0                  0
# 32742                  0                  0
# 55958                  1                  0

# %% [markdown]
# ### Расчет модели наивного Байеса
# \begin{equation}
# P(A\mid B) = \frac{P(B\mid A)\ P(A)}{P(B)}
# \end{equation}
# Для каждого параметра вычисляется его вероятность принять определенное значение - P(B). Для каждого класса вычисляется его вероятность (по факту, доля) - P(A). Затем вычисляется вероятность для каждого параметра принять определенное значение при определенном классе - P(B\A).
#
# По всем вычисленным значениям находится вероятность при известных параметрах принять какое-либо значение класса.

# %%
y = data_train['Response']
x = scaler.transform(data_train[columns])
bayes = GaussianNB().fit(x, y)

# %% [markdown]
# ### Предсказание данных

# %%
x_test = scaler.transform(data_test[columns])
data_test['target'] = bayes.predict(x_test)
data_test.head()
# Out:
#           Id  Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 17642  23510               1              26        1.000000               2
# 5613    7470               1              26        0.128174               2
# 6310    8414               1              26        0.128174               2
# 56870  75765               1              26        0.230713               2
# 5158    6858               2              26        0.487061               3
#
#        Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt       BMI  \
# 17642               3               1  0.462646  0.872559  0.341064  0.392822
# 5613                3               1  0.358154  0.636230  0.246826  0.467529
# 6310                3               1  0.358154  0.708984  0.205078  0.321533
# 56870               3               1  0.522461  0.745605  0.403809  0.615234
# 5158                3               1  0.208984  0.727051  0.261475  0.401123
#
#        Employment_Info_1  Employment_Info_2  Employment_Info_3  \
# 17642           0.059998                  9                  1
# 5613            0.049988                  9                  1
# 6310            0.024002                  9                  1
# 56870           1.000000                 12                  1
# 5158            0.059998                 12                  1
#
#        Employment_Info_4  Employment_Info_5  Employment_Info_6  InsuredInfo_1  \
# 17642           0.000000                  2           0.600098              1
# 5613            0.000000                  2          -1.000000              1
# 6310            0.006001                  2          -1.000000              2
# 56870           0.078003                  2           0.990234              1
# 5158            0.300049                  2           1.000000              1
#
#        InsuredInfo_2  InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  \
# 17642              2              8              3              1
# 5613               2              6              3              1
# 6310               2              8              3              1
# 56870              2              8              3              1
# 5158               2              3              3              3
#
#        InsuredInfo_6  InsuredInfo_7  Insurance_History_1  Insurance_History_2  \
# 17642              1              1                    2                    1
# 5613               1              1                    2                    1
# 6310               1              1                    1                    1
# 56870              1              1                    2                    1
# 5158               1              1                    2                    1
#
#        Insurance_History_3  Insurance_History_4  Insurance_History_5  \
# 17642                    3                    1         8.344650e-07
# 5613                     1                    3        -1.000000e+00
# 6310                     3                    1         6.666183e-04
# 56870                    3                    1         1.666546e-04
# 5158                     1                    3        -1.000000e+00
#
#        Insurance_History_7  Insurance_History_8  Insurance_History_9  \
# 17642                    1                    3                    2
# 5613                     3                    2                    3
# 6310                     2                    1                    2
# 56870                    1                    3                    2
# 5158                     3                    2                    3
#
#        Family_Hist_1  Family_Hist_2  Family_Hist_3  Family_Hist_4  \
# 17642              3      -1.000000           -1.0      -1.000000
# 5613               3       0.362305           -1.0       0.295654
# 6310               3       0.536133           -1.0       0.436523
# 56870              3      -1.000000           -1.0      -1.000000
# 5158               3       0.333252           -1.0       0.309814
#
#        Family_Hist_5  Medical_History_1  Medical_History_2  Medical_History_3  \
# 17642       0.250000               15.0                335                  2
# 5613       -1.000000                2.0                140                  2
# 6310       -1.000000                3.0                 81                  2
# 56870       0.598145                1.0                156                  2
# 5158       -1.000000                3.0                 16                  2
#
#        Medical_History_4  Medical_History_5  Medical_History_6  \
# 17642                  2                  1                  3
# 5613                   2                  1                  3
# 6310                   2                  1                  3
# 56870                  1                  1                  3
# 5158                   1                  1                  3
#
#        Medical_History_7  Medical_History_8  Medical_History_9  \
# 17642                  2                  2                  2
# 5613                   2                  2                  2
# 6310                   2                  2                  2
# 56870                  2                  2                  1
# 5158                   2                  2                  2
#
#        Medical_History_10  Medical_History_11  Medical_History_12  \
# 17642                -1.0                   3                   2
# 5613                 -1.0                   3                   2
# 6310                 -1.0                   3                   2
# 56870                -1.0                   3                   2
# 5158                 -1.0                   3                   2
#
#        Medical_History_13  Medical_History_14  Medical_History_15  \
# 17642                   3                   3                -1.0
# 5613                    3                   3                -1.0
# 6310                    3                   3                -1.0
# 56870                   3                   3               240.0
# 5158                    1                   3                -1.0
#
#        Medical_History_16  Medical_History_17  Medical_History_18  \
# 17642                   1                   3                   1
# 5613                    1                   3                   1
# 6310                    1                   3                   1
# 56870                   1                   3                   2
# 5158                    1                   3                   1
#
#        Medical_History_19  Medical_History_20  Medical_History_21  \
# 17642                   1                   2                   1
# 5613                    1                   2                   1
# 6310                    1                   2                   1
# 56870                   1                   2                   1
# 5158                    1                   2                   1
#
#        Medical_History_22  Medical_History_23  Medical_History_24  \
# 17642                   2                   3                -1.0
# 5613                    2                   3                -1.0
# 6310                    2                   3                -1.0
# 56870                   2                   1                -1.0
# 5158                    2                   3                -1.0
#
#        Medical_History_25  Medical_History_26  Medical_History_27  \
# 17642                   1                   3                   3
# 5613                    1                   3                   3
# 6310                    1                   3                   3
# 56870                   1                   3                   3
# 5158                    1                   3                   3
#
#        Medical_History_28  Medical_History_29  Medical_History_30  \
# 17642                   1                   3                   2
# 5613                    1                   3                   2
# 6310                    1                   3                   2
# 56870                   1                   1                   2
# 5158                    1                   3                   2
#
#        Medical_History_31  Medical_History_32  Medical_History_33  \
# 17642                   3                -1.0                   3
# 5613                    3                -1.0                   3
# 6310                    3                -1.0                   3
# 56870                   3                -1.0                   3
# 5158                    3                -1.0                   1
#
#        Medical_History_34  Medical_History_35  Medical_History_36  \
# 17642                   3                   1                   2
# 5613                    3                   1                   2
# 6310                    3                   1                   2
# 56870                   3                   1                   2
# 5158                    3                   1                   2
#
#        Medical_History_37  Medical_History_38  Medical_History_39  \
# 17642                   2                   1                   3
# 5613                    2                   1                   3
# 6310                    2                   1                   3
# 56870                   2                   1                   3
# 5158                    2                   1                   3
#
#        Medical_History_40  Medical_History_41  Medical_Keyword_1  \
# 17642                   3                   1                  0
# 5613                    3                   1                  0
# 6310                    3                   1                  0
# 56870                   3                   1                  0
# 5158                    3                   3                  0
#
#        Medical_Keyword_2  Medical_Keyword_3  Medical_Keyword_4  \
# 17642                  0                  0                  0
# 5613                   0                  0                  0
# 6310                   0                  0                  0
# 56870                  0                  0                  0
# 5158                   0                  0                  0
#
#        Medical_Keyword_5  Medical_Keyword_6  Medical_Keyword_7  \
# 17642                  0                  0                  0
# 5613                   0                  0                  0
# 6310                   0                  0                  0
# 56870                  0                  0                  0
# 5158                   0                  0                  0
#
#        Medical_Keyword_8  Medical_Keyword_9  Medical_Keyword_10  \
# 17642                  0                  0                   0
# 5613                   0                  0                   0
# 6310                   0                  0                   0
# 56870                  0                  0                   0
# 5158                   0                  0                   0
#
#        Medical_Keyword_11  Medical_Keyword_12  Medical_Keyword_13  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_14  Medical_Keyword_15  Medical_Keyword_16  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_17  Medical_Keyword_18  Medical_Keyword_19  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_20  Medical_Keyword_21  Medical_Keyword_22  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_23  Medical_Keyword_24  Medical_Keyword_25  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    1                   0                   0
#
#        Medical_Keyword_26  Medical_Keyword_27  Medical_Keyword_28  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_29  Medical_Keyword_30  Medical_Keyword_31  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_32  Medical_Keyword_33  Medical_Keyword_34  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_35  Medical_Keyword_36  Medical_Keyword_37  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   1                   0                   1
# 5158                    0                   0                   0
#
#        Medical_Keyword_38  Medical_Keyword_39  Medical_Keyword_40  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   1
#
#        Medical_Keyword_41  Medical_Keyword_42  Medical_Keyword_43  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_44  Medical_Keyword_45  Medical_Keyword_46  \
# 17642                   0                   0                   0
# 5613                    0                   0                   0
# 6310                    0                   0                   0
# 56870                   0                   0                   0
# 5158                    0                   0                   0
#
#        Medical_Keyword_47  Medical_Keyword_48  Response  Product_Info_2_2  \
# 17642                   0                   0         8                 1
# 5613                    0                   0         6                 4
# 6310                    0                   0         8                 2
# 56870                   0                   0         2                 3
# 5158                    0                   0         6                 3
#
#        Product_Info_2_1A  Product_Info_2_1B  Product_Info_2_1C  \
# 17642                  0                  0                  0
# 5613                   0                  0                  0
# 6310                   1                  0                  0
# 56870                  0                  0                  0
# 5158                   0                  0                  0
#
#        Product_Info_2_1D  Product_Info_2_1E  target
# 17642                  1                  0       4
# 5613                   1                  0       4
# 6310                   0                  0       4
# 56870                  1                  0       7
# 5158                   1                  0       4

# %% [markdown]
# ### Оценка модели

# %%
print('Байес:', cohen_kappa_score(data_test['Response'], data_test['target'], weights='quadratic'))
# Out:
# Байес: 0.19506590874215646

# %% [markdown]
# ### Матрица неточностей

# %%
print(confusion_matrix(data_test["target"], data_test["Response"]))
# Out:
# [[ 272  209   16    7   92  174   86  109]
#  [ 112  155    7    4   49   77   22   38]
#  [ 105  126   22    7   42   80   15   39]
#  [ 327  356  109  215  489 1031  750 2275]
#  [  41   59    2    0   29   40   12   10]
#  [  15   17    1    0   15   20    4    1]
#  [ 323  367   21   40  353  702  633  793]
#  [  37   18    2    9   41   87   92  676]]
